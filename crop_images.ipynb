# %% [markdown]
# <a href="https://colab.research.google.com/github/RachelLi15/Rubix_Solver/blob/main/crop_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Convert images in dataset to be 640x640 for use by YOLO model

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/Rubix Solver/images/1036.jpg')

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1080, 1920, 3)

# %%
cropped_image = img[300:940, 600:1240]
fix_img2 = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img2)

# %%
outPath = '/content/drive/MyDrive/Rubix Solver/cropped_imgs'
fullpath = os.path.join(outPath, 'cropped_1036.jpg')
cv2.imwrite(fullpath, cropped_image)
# Out:
# True

# %% [markdown]
# Way to convert all images simultaneously, does not work for my case as rubix cube's are not in the same coordinate place every time

# %%
# Another way to do it more efficiently, but does not work for my dataset as the rubix cubes aren't all in the same place
import cv2
import os

folder_path = '/content/drive/MyDrive/Rubix Solver/images'
outPath = '/content/drive/MyDrive/Rubix Solver/cropped_imgs'
for filename in os.listdir(folder_path):
  image_path = os.path.join(folder_path, filename)
  img = cv2.imread(image_path)
  cropped_image = img[220:860, 740:1380]
  fullpath = os.path.join(outPath, 'cropped_'+filename)
  cv2.imwrite(fullpath, cropped_image)
